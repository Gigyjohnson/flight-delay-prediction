# %%
import pandas as pd
import numpy as np

# %%
orgin_airport=pd.read_csv("C:\\Users\\Compaq\\Desktop\\gigy code file\\flight\\orgin_airport.csv")

# %%
flights=pd.read_csv("C:\\Users\\Compaq\\Desktop\\gigy code file\\flight\\flights.csv")
flights=pd.DataFrame(flights)
# Out:
# C:\Users\Compaq\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
airport=pd.read_csv("C:\\Users\\Compaq\\Desktop\\gigy code file\\flight\\airports.csv")

# %%
airport = airport.rename({'IATA_CODE':'ORIGIN_AIRPORT'}, axis=1)

# %%
airline=pd.read_csv("C:\\Users\\Compaq\\Desktop\\gigy code file\\flight\\airline.csv")
airline=pd.DataFrame(airline)
airline
# Out:
#     Unnamed: 0                       AIRLINE  AIRLINE_NUMBER
# 0            0          Alaska Airlines Inc.               0
# 1            1          Delta Air Lines Inc.               4
# 2            2         Skywest Airlines Inc.               8
# 3            3         United Air Lines Inc.              12
# 4            4                Virgin America              13
# 5            5               US Airways Inc.              11
# 6            6        Southwest Airlines Co.               9
# 7            7        Frontier Airlines Inc.               5
# 8            8        American Airlines Inc.               1
# 9            9        Hawaiian Airlines Inc.               6
# 10          10               JetBlue Airways               7
# 11          11              Spirit Air Lines              10
# 12          12   Atlantic Southeast Airlines               3
# 13          13  American Eagle Airlines Inc.               2

# %%
orgin_airport
# Out:
#      Unnamed: 0                                     ORIGIN_AIRPORT  \
# 0             0        Ted Stevens Anchorage International Airport
# 1             1                    Fairbanks International Airport
# 2             2                      Spokane International Airport
# 3             3                     Portland International Airport
# 4             4                  Los Angeles International Airport
# ..          ...                                                ...
# 307         307                   Golden Triangle Regional Airport
# 308         308                 Southwest Georgia Regional Airport
# 309         309                        Lea County Regional Airport
# 310         310                       Valley International Airport
# 311         311  Northeast Florida Regional Airport (St. August...
#
#      ORIGIN_AIRPORT_NUMBER
# 0                      277
# 1                       91
# 2                      268
# 3                      224
# ...

# %%
airport.columns.unique()
# Out:
# Index(['ORIGIN_AIRPORT', 'AIRPORT', 'CITY', 'STATE', 'COUNTRY', 'LATITUDE',
#        'LONGITUDE', 'Unnamed: 7', 'Unnamed: 8'],
#       dtype='object')

# %%
airport=pd.DataFrame(airport)
orgin_airport=pd.DataFrame(orgin_airport)

# %%
airport
# Out:
#                                   ORIGIN_AIRPORT  \
# 0    Ted Stevens Anchorage International Airport
# 1                Fairbanks International Airport
# 2                  Spokane International Airport
# 3                 Portland International Airport
# 4              Los Angeles International Airport
# ..                                           ...
# 317                                          WRG
# 318                                          WYS
# 319                                          XNA
# 320                                          YAK
# 321                                          YUM
#
#                                  AIRPORT                            CITY  \
# 0    Lehigh Valley International Airport                       Allentown
# 1               Abilene Regional Airport                         Abilene
# 2      Albuquerque International Sunport                     Albuquerque
# 3              Aberdeen Regional Airport                        Aberdeen
# ...

# %%
flights
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0        2015      1    1            4      AS             98      N407AS
# 1        2015      1    1            4      AA           2336      N3KUAA
# 2        2015      1    1            4      US            840      N171US
# 3        2015      1    1            4      AA            258      N3HYAA
# 4        2015      1    1            4      AS            135      N527AS
# ...       ...    ...  ...          ...     ...            ...         ...
# 5819074  2015     12   31            4      B6            688      N657JB
# 5819075  2015     12   31            4      B6            745      N828JB
# 5819076  2015     12   31            4      B6           1503      N913JB
# 5819077  2015     12   31            4      B6            333      N527JB
# 5819078  2015     12   31            4      B6            839      N534JB
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# ...

# %%
airport.values
# Out:
# array([['ABE', 'Lehigh Valley International Airport', 'Allentown', ...,
#         'USA', 40.652359999999994, -75.4404],
#        ['ABI', 'Abilene Regional Airport', 'Abilene', ..., 'USA',
#         32.41132, -99.6819],
#        ['ABQ', 'Albuquerque International Sunport', 'Albuquerque', ...,
#         'USA', 35.04022, -106.60918999999998],
#        ...,
#        ['XNA', 'Northwest Arkansas Regional Airport',
#         'Fayetteville/Springdale/Rogers', ..., 'USA', 36.28187,
#         -94.30681],
#        ['YAK', 'Yakutat Airport', 'Yakutat', ..., 'USA', 59.50336,
#         -139.66023],
#        ['YUM', 'Yuma International Airport', 'Yuma', ..., 'USA',
#         32.65658, -114.60597]], dtype=object)

# %%
airport_origin = pd.merge(airport,orgin_airport )
airport_origin.columns.unique
# Out:
# <bound method Index.unique of Index(['ORIGIN_AIRPORT', 'AIRPORT', 'CITY', 'STATE', 'COUNTRY', 'LATITUDE',
#        'LONGITUDE', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 0',
#        'ORIGIN_AIRPORT_NUMBER'],
#       dtype='object')>

# %%
airport_origin=pd.DataFrame(airport_origin)
airport_origin=airport_origin.drop(['Unnamed: 7'],axis=1)

# %%
import datetime,warnings
flights['DATE'] = pd.to_datetime(flights[['YEAR','MONTH', 'DAY']])

# %%
flightsdemo=flights
flightsdemo.shape
flights.shape
# Out:
# (5819079, 32)

# %%
list1=['AS', 'AA', 'US', 'DL', 'NK', 'UA', 'HA', 'B6', 'OO', 'EV', 'MQ',
       'F9', 'WN', 'VX']
airline["AIRLINE"]=list1
airline
#flight_airline=pd.merge(airline,flights,how ='inner', on ='AIRLINE')
# Out:
#     Unnamed: 0 AIRLINE  AIRLINE_NUMBER
# 0            0      AS               0
# 1            1      AA               4
# 2            2      US               8
# 3            3      DL              12
# 4            4      NK              13
# 5            5      UA              11
# 6            6      HA               9
# 7            7      B6               5
# 8            8      OO               1
# 9            9      EV               6
# 10          10      MQ               7
# 11          11      F9              10
# 12          12      WN               3
# 13          13      VX               2

# %%
airport_origin = pd.merge(airport_origin,flightsdemo)

# %%
for i in range(0,11):
    for j in range(0,11):
        col1=list1[i]
        col2=list2[j]
        print(col1,col2)
# Out:
# ORIGIN_AIRPORT YEAR
# ORIGIN_AIRPORT MONTH
# ORIGIN_AIRPORT DAY
# ORIGIN_AIRPORT DAY_OF_WEEK
# ORIGIN_AIRPORT AIRLINE
# ORIGIN_AIRPORT FLIGHT_NUMBER
# ORIGIN_AIRPORT TAIL_NUMBER
# ORIGIN_AIRPORT ORIGIN_AIRPORT
# ORIGIN_AIRPORT DESTINATION_AIRPORT
# ORIGIN_AIRPORT SCHEDULED_DEPARTURE
# ORIGIN_AIRPORT DEPARTURE_TIME
# AIRPORT YEAR
# AIRPORT MONTH
# AIRPORT DAY
# AIRPORT DAY_OF_WEEK
# AIRPORT AIRLINE
# AIRPORT FLIGHT_NUMBER
# AIRPORT TAIL_NUMBER
# AIRPORT ORIGIN_AIRPORT
# AIRPORT DESTINATION_AIRPORT
# AIRPORT SCHEDULED_DEPARTURE
# AIRPORT DEPARTURE_TIME
# CITY YEAR
# CITY MONTH
# CITY DAY
# CITY DAY_OF_WEEK
# CITY AIRLINE
# CITY FLIGHT_NUMBER
# CITY TAIL_NUMBER
# CITY ORIGIN_AIRPORT
# CITY DESTINATION_AIRPORT
# CITY SCHEDULED_DEPARTURE
# CITY DEPARTURE_TIME
# STATE YEAR
# STATE MONTH
# STATE DAY
# STATE DAY_OF_WEEK
# STATE AIRLINE
# STATE FLIGHT_NUMBER
# STATE TAIL_NUMBER
# STATE ORIGIN_AIRPORT
# STATE DESTINATION_AIRPORT
# STATE SCHEDULED_DEPARTURE
# STATE DEPARTURE_TIME
# ...

# %%
airport_origin
flights.ORIGIN_AIRPORT[1]
# Out:
# 'LAX'

# %%
flights['ORIGIN_AIRPORT'].unique()
# Out:
# array(['ANC', 'LAX', 'SFO', 'SEA', 'LAS', 'DEN', 'SLC', 'PDX', 'FAI',
#        'MSP', 'PHX', 'SJU', 'PBG', 'IAG', 'PSE', 'BQN', 'ORD', 'GEG',
#        'HNL', 'ONT', 'MCO', 'BOS', 'HIB', 'ABR', 'MAF', 'DFW', 'MKE',
#        'IAH', 'BNA', 'BRO', 'VPS', 'BOI', 'BJI', 'SGF', 'PHL', 'SBN',
#        'RDD', 'EUG', 'IAD', 'BUF', 'PWM', 'JFK', 'CRP', 'PIA', 'FAT',
#        'SMF', 'AUS', 'MCI', 'ATL', 'JAX', 'MFR', 'IDA', 'MSN', 'DCA',
#        'SAT', 'CHS', 'SBA', 'SMX', 'IND', 'CLE', 'GSP', 'BDL', 'ABI',
#        'RIC', 'BFL', 'OMA', 'RDM', 'FLL', 'CID', 'TPA', 'SYR', 'ROC',
#        'TYR', 'LAN', 'XNA', 'GSO', 'EWR', 'PBI', 'RSW', 'OAK', 'PVD',
#        'RNO', 'PIT', 'ABQ', 'MIA', 'BWI', 'LGA', 'TUL', 'LIT', 'MSY',
#        'OKC', 'ATW', 'PNS', 'MEM', 'TYS', 'MHT', 'SAV', 'CLT', 'GRB',
#        'ABE', 'JAN', 'OAJ', 'FAR', 'ERI', 'LEX', 'CWA', 'MSO', 'TTN',
#        'AMA', 'CLL', 'HOU', 'JLN', 'MLI', 'RDU', 'CVG', 'MHK', 'MOB',
# ...

# %%
flights2=flights.iloc[0:469968,:]
flights2.shape 
flights2
# Out:
#         YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0       2015      1    1            4      AS             98      N407AS
# 1       2015      1    1            4      AA           2336      N3KUAA
# 2       2015      1    1            4      US            840      N171US
# 3       2015      1    1            4      AA            258      N3HYAA
# 4       2015      1    1            4      AS            135      N527AS
# ...      ...    ...  ...          ...     ...            ...         ...
# 469963  2015      1   31            6      B6            839      N658JB
# 469964  2015      1   31            6      DL           1887      N855NW
# 469965  2015      1   31            6      F9            300      N218FR
# 469966  2015      1   31            6      F9            422      N954FR
# 469967  2015      1   31            6      UA           1104      N73251
#
#        ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# ...

# %%
airport_origin
# Out:
#                                         ORIGIN_AIRPORT  \
# 0          Ted Stevens Anchorage International Airport
# 1                      Fairbanks International Airport
# 2                        Spokane International Airport
# 3                       Portland International Airport
# 4                    Los Angeles International Airport
# ..                                                 ...
# 307                   Golden Triangle Regional Airport
# 308                 Southwest Georgia Regional Airport
# 309                        Lea County Regional Airport
# 310                       Valley International Airport
# 311  Northeast Florida Regional Airport (St. August...
#
#                                           AIRPORT           CITY STATE  \
# 0             Lehigh Valley International Airport      Allentown    PA
# 1                        Abilene Regional Airport        Abilene    TX
# 2               Albuquerque International Sunport    Albuquerque    NM
# ...

# %%
airline
# Out:
#     Unnamed: 0 AIRLINE  AIRLINE_NUMBER
# 0            0      AS               0
# 1            1      AA               4
# 2            2      US               8
# 3            3      DL              12
# 4            4      NK              13
# 5            5      UA              11
# 6            6      HA               9
# 7            7      B6               5
# 8            8      OO               1
# 9            9      EV               6
# 10          10      MQ               7
# 11          11      F9              10
# 12          12      WN               3
# 13          13      VX               2

# %%
flights2=pd.merge(flights2,airline,how='outer',on='AIRLINE')
flights2
# Out:
#         YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0       2015      1    1            4      AS             98      N407AS
# 1       2015      1    1            4      AS            135      N527AS
# 2       2015      1    1            4      AS            108      N309AS
# 3       2015      1    1            4      AS            122      N413AS
# 4       2015      1    1            4      AS            130      N457AS
# ...      ...    ...  ...          ...     ...            ...         ...
# 469963  2015      1   31            6      VX            942      N640VA
# 469964  2015      1   31            6      VX            260      N843VA
# 469965  2015      1   31            6      VX            748      N623VA
# 469966  2015      1   31            6      VX            810      N855VA
# 469967  2015      1   31            6      VX            260      N843VA
#
#        ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# ...

# %%
flihts2=flights2.drop('Unnamed: 0',axis=1)

# %%
flights2.isnull().sum()
# Out:
# YEAR                        0
# MONTH                       0
# DAY                         0
# DAY_OF_WEEK                 0
# AIRLINE                     0
# FLIGHT_NUMBER               0
# TAIL_NUMBER              2782
# ORIGIN_AIRPORT              0
# DESTINATION_AIRPORT         0
# SCHEDULED_DEPARTURE         0
# DEPARTURE_TIME          11657
# DEPARTURE_DELAY         11657
# TAXI_OUT                11876
# WHEELS_OFF              11876
# SCHEDULED_TIME              0
# ELAPSED_TIME            12955
# AIR_TIME                12955
# DISTANCE                    0
# WHEELS_ON               12271
# TAXI_IN                 12271
# SCHEDULED_ARRIVAL           0
# ARRIVAL_TIME            12271
# ARRIVAL_DELAY           12955
# DIVERTED                    0
# CANCELLED                   0
# CANCELLATION_REASON    457986
# AIR_SYSTEM_DELAY       374017
# SECURITY_DELAY         374017
# AIRLINE_DELAY          374017
# LATE_AIRCRAFT_DELAY    374017
# WEATHER_DELAY          374017
# ...

# %%
flights2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 469968 entries, 0 to 469967
# Data columns (total 34 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   YEAR                 469968 non-null  int64
#  1   MONTH                469968 non-null  int64
#  2   DAY                  469968 non-null  int64
#  3   DAY_OF_WEEK          469968 non-null  int64
#  4   AIRLINE              469968 non-null  object
#  5   FLIGHT_NUMBER        469968 non-null  int64
#  6   TAIL_NUMBER          467186 non-null  object
#  7   ORIGIN_AIRPORT       469968 non-null  object
#  8   DESTINATION_AIRPORT  469968 non-null  object
#  9   SCHEDULED_DEPARTURE  469968 non-null  int64
#  10  DEPARTURE_TIME       458311 non-null  float64
#  11  DEPARTURE_DELAY      458311 non-null  float64
#  12  TAXI_OUT             458092 non-null  float64
#  13  WHEELS_OFF           458092 non-null  float64
#  14  SCHEDULED_TIME       469968 non-null  float64
# ...

# %%
flights2.shape
# Out:
# (469968, 34)

# %%
def format_hour(chain):
    if pd.isnull(chain):
        return np.nan
    else:
        if chain == 2400: chain = 0
        chain = "{0:04d}".format(int(chain))
        hour = datetime.time(int(chain[0:2]), int(chain[2:4]))
        return hour

# %%
flights2['DEPARTURE_TIME'] = flights2['DEPARTURE_TIME'].apply(format_hour)
flights2['SCHEDULED_DEPARTURE'] = flights2['SCHEDULED_DEPARTURE'].apply(format_hour)
#lights2['SCHEDULED_DEPARTURE'] = flights2['SCHEDULED_DEPARTURE'].apply(format_hour)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-d0934ba7e736> in <module>
# ----> 1 flights2['DEPARTURE_TIME'] = flights2['DEPARTURE_TIME'].apply(format_hour)
#       2 flights2['SCHEDULED_DEPARTURE'] = flights2['SCHEDULED_DEPARTURE'].apply(format_hour)
#       3 #flights2['SCHEDULED_DEPARTURE'] = flights2['SCHEDULED_DEPARTURE'].apply(format_hour)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-24-3f5afb1ab199> in format_hour(chain)
#       4     else:
# ...

# %%
flights2['ARRIVAL_TIME']
# Out:
# 0          408.0
# 1          259.0
# 2          455.0
# 3          507.0
# 4          545.0
#            ...
# 469963    2028.0
# 469964    2111.0
# 469965    2239.0
# 469966    2222.0
# 469967     543.0
# Name: ARRIVAL_TIME, Length: 469968, dtype: float64

# %%
airline
# Out:
#     Unnamed: 0 AIRLINE  AIRLINE_NUMBER
# 0            0      AS               0
# 1            1      AA               4
# 2            2      US               8
# 3            3      DL              12
# 4            4      NK              13
# 5            5      UA              11
# 6            6      HA               9
# 7            7      B6               5
# 8            8      OO               1
# 9            9      EV               6
# 10          10      MQ               7
# 11          11      F9              10
# 12          12      WN               3
# 13          13      VX               2

# %%
import sklearn.preprocessing as pre

# %%
a=np.array(flights2['AIRLINE_NUMBER'])
a
# Out:
# array([0, 0, 0, ..., 2, 2, 2], dtype=int64)

# %%
le=pre.LabelEncoder()
dfencoded=le.fit_transform(a)

# %%
flights2.shape
# Out:
# (469968, 34)

# %%
flights2=flights2.rename({'AIRLINE_NUMBER':'AIRLINE_NAME'}, axis=1)
flights2['AIRLINE_NAME']=dfencoded

# %%
flights2['DESTINATION_AIRPORT']
# Out:
# 0         SEA
# 1         ANC
# 2         SEA
# 3         PDX
# 4         SEA
#          ...
# 469963    LAX
# 469964    LAS
# 469965    SEA
# 469966    PDX
# 469967    JFK
# Name: DESTINATION_AIRPORT, Length: 469968, dtype: object

# %%
#flights['AIRPORT']=airport_origin['AIRPORT']
#flights2.columns[AIRPORT]

# %%
data=flights2[['DAY_OF_WEEK','AIRLINE','FLIGHT_NUMBER','ORIGIN_AIRPORT','DESTINATION_AIRPORT','SCHEDULED_DEPARTURE','DEPARTURE_TIME','DEPARTURE_DELAY','AIRLINE_NAME','ARRIVAL_TIME']]

# %%
flights2['ARRIVAL_TIME']
# Out:
# 0          408.0
# 1          259.0
# 2          455.0
# 3          507.0
# 4          545.0
#            ...
# 469963    2028.0
# 469964    2111.0
# 469965    2239.0
# 469966    2222.0
# 469967     543.0
# Name: ARRIVAL_TIME, Length: 469968, dtype: float64

# %%
data
# Out:
#         DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 0                 4      AS             98            ANC                 SEA
# 1                 4      AS            135            SEA                 ANC
# 2                 4      AS            108            ANC                 SEA
# 3                 4      AS            122            ANC                 PDX
# 4                 4      AS            130            FAI                 SEA
# ...             ...     ...            ...            ...                 ...
# 469963            6      VX            942            SFO                 LAX
# 469964            6      VX            260            SFO                 LAS
# 469965            6      VX            748            SFO                 SEA
# 469966            6      VX            810            SFO                 PDX
# 469967            6      VX            260            LAS                 JFK
#
# ...

# %%
def format_hour(chain):
    if pd.isnull(chain):
        return np.nan
    else:
        if chain == 2400: chain = 0
        chain = "{0:04d}".format(int(chain))
        hour = datetime.time(int(chain[0:2]), int(chain[2:4]))
        return hour

# %%
#data['SCHEDULED_DEPARTURE'] = data['SCHEDULED_DEPARTURE'].apply(format_hour)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-0b891f4f491a> in <module>
# ----> 1 data['SCHEDULED_DEPARTURE'] = data['SCHEDULED_DEPARTURE'].apply(format_hour)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-41-3f5afb1ab199> in format_hour(chain)
#       4     else:
#       5         if chain == 2400: chain = 0
# ----> 6         chain = "{0:04d}".format(int(chain))
#       7         hour = datetime.time(int(chain[0:2]), int(chain[2:4]))
#       8         return hour
#
# ...

# %%
data['DEPARTURE_TIME'] = data['DEPARTURE_TIME'].apply(format_hour)
# Out:
# <ipython-input-181-fe9d726304a3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['DEPARTURE_TIME'] = data['DEPARTURE_TIME'].apply(format_hour)

# %%
data['DEPARTURE_TIME']
data.columns
# Out:
# Index(['DAY_OF_WEEK', 'AIRLINE', 'FLIGHT_NUMBER', 'ORIGIN_AIRPORT',
#        'DESTINATION_AIRPORT', 'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME',
#        'DEPARTURE_DELAY', 'AIRLINE_NAME', 'ARRIVAL_TIME'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
corr=data.corr()
corr
plt.plot(data['DESTINATION_AIRPORT'],data['DEPARTURE_DELAY'])
#plt.show()
#ax=sns.heatmap(corr)
sns.pairplot(data)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 469968 entries, 0 to 469967
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   DAY_OF_WEEK          469968 non-null  int64
#  1   AIRLINE              469968 non-null  object
#  2   FLIGHT_NUMBER        469968 non-null  int64
#  3   ORIGIN_AIRPORT       469968 non-null  object
#  4   DESTINATION_AIRPORT  469968 non-null  object
#  5   SCHEDULED_DEPARTURE  469968 non-null  object
#  6   DEPARTURE_TIME       458311 non-null  object
#  7   DEPARTURE_DELAY      458311 non-null  float64
#  8   AIRLINE_NAME         469968 non-null  int64
#  9   ARRIVAL_TIME         457697 non-null  object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 39.4+ MB

# %%
data.isna().values.any()
# Out:
# True

# %%
data.shape
dataorg=data
dataorg.shape
data.shape
# Out:
# (469968, 10)

# %%
dataorg= dataorg.dropna()

# %%
dataorg.isna().values.any()
# Out:
# False

# %%
x=dataorg[['DAY_OF_WEEK','AIRLINE','FLIGHT_NUMBER','ORIGIN_AIRPORT','DESTINATION_AIRPORT','SCHEDULED_DEPARTURE','DEPARTURE_TIME','AIRLINE_NAME','ARRIVAL_TIME']]

# %%
y=dataorg[['DEPARTURE_DELAY']]

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2)

# %%
import sklearn.tree as tree
clf=tree.DecisionTreeClassifier()

# %%
y
# Out:
#         DEPARTURE_DELAY
# 0                 -11.0
# 1                  -1.0
# 2                  -4.0
# 3                  -4.0
# 4                  -8.0
# ...                 ...
# 469963             -3.0
# 469964             -6.0
# 469965             -4.0
# 469966             -5.0
# 469967              1.0
#
# [457697 rows x 1 columns]

# %%
#x
le=pre.LabelEncoder()
#x['ARRIVAL_TIME']=le.fit_transform(x['ARRIVAL_TIME'])

xo=x.iloc[0:10000,0:9]
yo=y.iloc[0:10000,:]
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(xo,yo,test_size=0.2)

# %%
ytest
# Out:
#       DEPARTURE_DELAY
# 5446             10.0
# 8251            -11.0
# 9849             -8.0
# 353             -12.0
# 3901             -6.0
# ...               ...
# 5072            -14.0
# 6741             -3.0
# 5808             12.0
# 3500             -6.0
# 2671            -11.0
#
# [2000 rows x 1 columns]

# %%
model=clf.fit(xo,yo)
yfinalvalue=model.predict(xtest)
yfinalvalue
# Out:
# array([ 10., -11.,  -8., ...,  12.,  -6., -11.])

# %%
import pickle
filename = 'finalized_model_flightdelay.sav'
pickle.dump(model, open(filename, 'wb'))
result =model.score(xtest, ytest)
result
# Out:
# 1.0

# %%
# load the model from disk
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(X_test, Y_test)
print(result)
